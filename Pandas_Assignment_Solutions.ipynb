# %% [markdown]
# Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
df.loc[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Q4. How do you rename columns in a Pandas DataFrame?

# %%
df.rename(columns={'PassengerId':'Id','Pclass':'Class'},inplace='true')
df
# Out:
#       Id  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Q5. How do you drop columns in a Pandas DataFrame?

# %%
df.drop(['Sex','Survived','Age','Ticket'], axis=1)
# Out:
#       Id  Class                                               Name  SibSp  \
# 0      1      3                            Braund, Mr. Owen Harris      1
# 1      2      1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2      3      3                             Heikkinen, Miss. Laina      0
# 3      4      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4      5      3                           Allen, Mr. William Henry      0
# ..   ...    ...                                                ...    ...
# 886  887      2                              Montvila, Rev. Juozas      0
# 887  888      1                       Graham, Miss. Margaret Edith      0
# 888  889      3           Johnston, Miss. Catherine Helen "Carrie"      1
# 889  890      1                              Behr, Mr. Karl Howell      0
# 890  891      3                                Dooley, Mr. Patrick      0
#
#      Parch     Fare Cabin Embarked
# 0        0   7.2500   NaN        S
# ...

# %% [markdown]
# Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
df.isnull().sum()
# Out:
# Id            0
# Survived      0
# Class         0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df.fillna('Unknown')
# Out:
#       Id  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %% [raw]
# Q9. How do you concatenate two Pandas DataFrames?

# %%
df1=df[['Id','Fare']]
df2=df[['Id','Name','Class']]
df3=pd.concat([df1,df2])
df3
# Out:
#       Id     Fare                                      Name  Class
# 0      1   7.2500                                       NaN    NaN
# 1      2  71.2833                                       NaN    NaN
# 2      3   7.9250                                       NaN    NaN
# 3      4  53.1000                                       NaN    NaN
# 4      5   8.0500                                       NaN    NaN
# ..   ...      ...                                       ...    ...
# 886  887      NaN                     Montvila, Rev. Juozas    2.0
# 887  888      NaN              Graham, Miss. Margaret Edith    1.0
# 888  889      NaN  Johnston, Miss. Catherine Helen "Carrie"    3.0
# 889  890      NaN                     Behr, Mr. Karl Howell    1.0
# 890  891      NaN                       Dooley, Mr. Patrick    3.0
#
# [1782 rows x 4 columns]

# %% [markdown]
# Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
df1.merge(df2,how='left' )
# Out:
#       Id     Fare                                               Name  Class
# 0      1   7.2500                            Braund, Mr. Owen Harris      3
# 1      2  71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2      3   7.9250                             Heikkinen, Miss. Laina      3
# 3      4  53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4      5   8.0500                           Allen, Mr. William Henry      3
# ..   ...      ...                                                ...    ...
# 886  887  13.0000                              Montvila, Rev. Juozas      2
# 887  888  30.0000                       Graham, Miss. Margaret Edith      1
# 888  889  23.4500           Johnston, Miss. Catherine Helen "Carrie"      3
# 889  890  30.0000                              Behr, Mr. Karl Howell      1
# 890  891   7.7500                                Dooley, Mr. Patrick      3
#
# [891 rows x 4 columns]

# %% [markdown]
# Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
df.groupby(['Name']).groups
df.aggregate('Age')

# %% [markdown]
# Q12. How do you pivot a Pandas DataFramataFrame?

# %%
df = pd.DataFrame({'Name': ['A', 'B', 'C'],
      'Qua': ['Masters', 'Graduate', 'Graduate'],
      'Age': [7, 5, 9]})
  
print(df)
df1 = df.pivot(index = ['Age'], columns = 'Name' , values = ['Qua'])
df1
# Out:
#   Name       Qua  Age
# 0    A   Masters    7
# 1    B  Graduate    5
# 2    C  Graduate    9
#           Qua
# Name        A         B         C
# Age
# 5         NaN  Graduate       NaN
# 7     Masters       NaN       NaN
# 9         NaN       NaN  Graduate

# %% [markdown]
# Q13. How do you change the data type of a column in a Pandas DataFataFrame?

# %%
df['Age'].dtypes
# Out:
# dtype('float64')

# %%
df=df.astype({'Age':str})
df['Age'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# Q14. How do you sort a Pandas DataFrame by a specific dataFrame?

# %%
df.sort_values(by=['Name','Age'])
# Out:
#       Id  Survived  Class                                   Name     Sex  \
# 845  846         0      3                    Abbing, Mr. Anthony    male
# 746  747         0      3            Abbott, Mr. Rossmore Edward    male
# 279  280         1      3       Abbott, Mrs. Stanton (Rosa Hunt)  female
# 308  309         0      2                    Abelson, Mr. Samuel    male
# 874  875         1      2  Abelson, Mrs. Samuel (Hannah Wizosky)  female
# ..   ...       ...    ...                                    ...     ...
# 286  287         1      3                de Mulder, Mr. Theodore    male
# 282  283         0      3              de Pelsmaeker, Mr. Alfons    male
# 361  362         0      2              del Carlo, Mr. Sebastiano    male
# 153  154         0      3        van Billiard, Mr. Austin Blyler    male
# 868  869         0      3            van Melkebeke, Mr. Philemon    male
#
#       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Q15. How do you create a copy of a Pandas DataFrame
# Ans:
# By default, the copy is a "deep copy" meaning that any changes made in the original DataFrame will NOT be reflected in the copy

# %%
df_copy=df.copy()
df_copy
# Out:
#       Id  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
df.loc[(df['Age']>20) &(df['Sex']=='male')]
# Out:
#       Id  Survived  Class                           Name   Sex   Age  SibSp  \
# 0      1         0      3        Braund, Mr. Owen Harris  male  22.0      1
# 4      5         0      3       Allen, Mr. William Henry  male  35.0      0
# 6      7         0      1        McCarthy, Mr. Timothy J  male  54.0      0
# 13    14         0      3    Andersson, Mr. Anders Johan  male  39.0      1
# 20    21         0      2           Fynney, Mr. Joseph J  male  35.0      0
# ..   ...       ...    ...                            ...   ...   ...    ...
# 883  884         0      2  Banfield, Mr. Frederick James  male  28.0      0
# 884  885         0      3         Sutehall, Mr. Henry Jr  male  25.0      0
# 886  887         0      2          Montvila, Rev. Juozas  male  27.0      0
# 889  890         1      1          Behr, Mr. Karl Howell  male  26.0      0
# 890  891         0      3            Dooley, Mr. Patrick  male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Q17. How do you calculate the mean of a column in a Pandas DataFramr labels?

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df['Age'].std()
# Out:
# 14.526497332334044

# %% [markdown]
# Q19. How do you calculate the correlation between two columns in a Pandas Datr labels?

# %%
df['Class'].corr(df['Age'])
# Out:
# -0.36922601531551735

# %% [markdown]
# Q20. How do you select specific columns in a DataFrame using their labels?

# %%
df[['Class','Age']]
# Out:
#      Class   Age
# Id
# 1        3  22.0
# 2        1  38.0
# 3        3  26.0
# 4        1  35.0
# 5        3  35.0
# ..     ...   ...
# 887      2  27.0
# 888      1  19.0
# 889      3   NaN
# 890      1  26.0
# 891      3  32.0
#
# [891 rows x 2 columns]

# %% [raw]
# Q21. How do you select specific rows in a DataFrame using their indexes?

# %%
df.set_index(['Id'], inplace =True)  #accessing names by making name as index
df.iloc[0:5]
# Out:
#     Survived  Class     Sex   Age  SibSp  Parch            Ticket     Fare  \
# Id
# 1          0      3    male  22.0      1      0         A/5 21171   7.2500
# 2          1      1  female  38.0      1      0          PC 17599  71.2833
# 3          1      3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 4          1      1  female  35.0      1      0            113803  53.1000
# 5          0      3    male  35.0      0      0            373450   8.0500
#
#    Cabin Embarked  Total_Fare
# Id
# 1    NaN        S    0.870000
# 2    C85        C    8.553996
# 3    NaN        S    0.951000
# 4   C123        S    6.372000
# 5    NaN        S    0.966000

# %% [markdown]
# Q22. How do you sort a DataFrame by a specific column Pandas?

# %%
df.sort_values(by='Age')
# Out:
#       Id  Survived  Class                                      Name     Sex  \
# 803  804         1      3           Thomas, Master. Assad Alexander    male
# 755  756         1      2                 Hamalainen, Master. Viljo    male
# 644  645         1      3                    Baclini, Miss. Eugenie  female
# 469  470         1      3             Baclini, Miss. Helene Barbara  female
# 78    79         1      2             Caldwell, Master. Alden Gates    male
# ..   ...       ...    ...                                       ...     ...
# 859  860         0      3                          Razi, Mr. Raihed    male
# 863  864         0      3         Sage, Miss. Dorothy Edith "Dolly"  female
# 868  869         0      3               van Melkebeke, Mr. Philemon    male
# 878  879         0      3                        Laleff, Mr. Kristo    male
# 888  889         0      3  Johnston, Miss. Catherine Helen "Carrie"  female
#
# ...

# %% [markdown]
# Q23. How do you create a new column in a DataFrame based on the values of another column Pandas?

# %%
df['Total_Fare']=df['Fare']*0.12
df
# Out:
#       Id  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Q24. How do you remove duplicates from a DataFrame  Pandas?

# %%
df.drop_duplicates()
# Out:
#       Id  Survived  Class                                               Name  \
# 0      1         0      3                            Braund, Mr. Owen Harris
# 1      2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1      3                             Heikkinen, Miss. Laina
# 3      4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0      3                           Allen, Mr. William Henry
# ..   ...       ...    ...                                                ...
# 886  887         0      2                              Montvila, Rev. Juozas
# 887  888         1      1                       Graham, Miss. Margaret Edith
# 888  889         0      3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1      1                              Behr, Mr. Karl Howell
# 890  891         0      3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Q25. What is the difference between .loc and .iloc in Pandas?
# Ans:
# .iloc - will displays the default index
# .loc  - will displays the manually set index
#
# The loc() function is label based data selecting method which means that we have to pass
# the name of the row or column which we want to select. This method includes the last element
# of the range passed in it, unlike iloc(). loc() can accept the boolean data unlike iloc().
#
# The iloc() function is an indexed-based selecting method which means that we have to pass
# an integer index in the method to select a specific row/column. This method does not include
# the last element of the range passed in it unlike loc().
# iloc() does not accept the boolean data unlike loc().

# %%
df.loc[(df['Sex']=='male') & (df['Class']==3)]
# Out:
#       Id  Survived  Class                            Name   Sex   Age  SibSp  \
# 0      1         0      3         Braund, Mr. Owen Harris  male  22.0      1
# 4      5         0      3        Allen, Mr. William Henry  male  35.0      0
# 5      6         0      3                Moran, Mr. James  male   NaN      0
# 7      8         0      3  Palsson, Master. Gosta Leonard  male   2.0      3
# 12    13         0      3  Saundercock, Mr. William Henry  male  20.0      0
# ..   ...       ...    ...                             ...   ...   ...    ...
# 877  878         0      3            Petroff, Mr. Nedelio  male  19.0      0
# 878  879         0      3              Laleff, Mr. Kristo  male   NaN      0
# 881  882         0      3              Markun, Mr. Johann  male  33.0      0
# 884  885         0      3          Sutehall, Mr. Henry Jr  male  25.0      0
# 890  891         0      3             Dooley, Mr. Patrick  male  32.0      0
#
# ...

# %%
df.loc[0:5]
# Out:
#    Id  Survived  Class                                               Name  \
# 0   1         0      3                            Braund, Mr. Owen Harris
# 1   2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1      3                             Heikkinen, Miss. Laina
# 3   4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0      3                           Allen, Mr. William Henry
# 5   6         0      3                                   Moran, Mr. James
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
# ...

# %%
df.iloc[0:5]
# Out:
#    Id  Survived  Class                                               Name  \
# 0   1         0      3                            Braund, Mr. Owen Harris
# 1   2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1      3                             Heikkinen, Miss. Laina
# 3   4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0      3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
